# %% [markdown]
# <a href="https://colab.research.google.com/github/OSCARDAN37/Calcular-cambio-if-else-/blob/main/El_profe_Act_12_Cambio_Oscar_Flores_1389.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Oscar Flores NL = 19 Fecha 26/mar/2026
# ### Calculado el cambio usando if else
# ### Mirar diagramade flujo
# <img src="https://raw.githubusercontent.com/OSCARDAN37/Calcular-cambio-if-else-/refs/heads/main/calcular-cambio.jpg" width="300" height="300" alt="Texto descriptivo">
#
# ## Las Variables
# 1. CP --> Costo del producto
# 2. CD --> Cantidad de dinero
# 3. Cambio
#
# ## Formulas
# * $Cambio = CD - CP$
#
# ## Diagrama de Flujo LucidChart
# <img src="https://raw.githubusercontent.com/OSCARDAN37/Calcular-cambio-if-else-/refs/heads/main/DF%20Calcular%20cambio.png" width="350" height="500" alt="Texto descriptivo">

# %%
# Para cuando es verdadero (si)
# Calculando el cambio usando if else
# datos de entrada CD , CP
# mostrar cambio si es falso
# Si es verdadero mostrar no alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
if CP > CD:
    print("No alcanza")
else:
    Cambio = CD - CP
    print("El cambio es: ", Cambio)
print("fin del programa")
print("Programa realizado por Oscar Flores NL = 19")
# Out:
# Ingrese el costo del producto: 500
# Ingrese la cantidad de dinero: 400
# No alcanza
# fin del programa
# Programa realizado por Oscar Flores NL = 19

# %%
# Para cuando es falso (no)
# Calculando el cambio usando if else
# datos de entrada CD , CP
# mostrar cambio si es falso
# Si es verdadero mostrar no alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
if CP > CD:
    print("No alcanza")
else:
    Cambio = CD - CP
    print("El cambio es: ", Cambio)
print("fin del programa")
print("Programa realizado por Oscar Flores NL = 19")
# Out:
# Ingrese el costo del producto: 250
# Ingrese la cantidad de dinero: 300
# El cambio es:  50.0
# fin del programa
# Programa realizado por Oscar Flores NL = 19

# %% [markdown]
# ## Relacion entre codigo y diagrama de flujo
# <img src="https://raw.githubusercontent.com/OSCARDAN37/Calcular-cambio-if-else-/refs/heads/main/tldraw%20codigo%20DF.png" width="800" height="500" alt="Texto descriptivo">
